# %%
import pandas as pd

# 11
fao = pd.read_csv('C:\\Users\\SILVERS\\Desktop\\ds_tutorial\\FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding ='latin-1')
print(fao)
# fao_af = fao.groupby(['Item', 'Y2014', 'Y2017']).count()
# print(fao_af)
# af = fao_af.groupby(['Animal fats']).count()

# 12
fao.loc[: , 'Y2015'].mean()

fao[['Y2015']].std()

# 13
md = fao[['Y2016']].isnull().sum()
print(md)
mdt = fao[['Y2016']].sum()
print(mdt)
pc = (md / mdt) * 100
print(pc)

# 14
yc = fao[['Element Code', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']]
print(yc)
yc1 = yc.groupby(['Element Code']).max()
print(yc1)

# 15
jc = fao[['Element', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']]
print(jc)
#ele = jc.loc['Import Quantity', : ].reset_index(drop=True)
#print(ele)

# 16
bc = ele.loc['Production', 'Y2014'].sum()
print(bc)

# 17 & 18
dd = fao[['Y2018', 'Element']]
print(dd)
dd.groupby(['Element']).max()
dd.groupby(['Element']).min()

# 19
gc = fao[['Area', 'Element', 'Y2018']]
fao1 = fao.to_csv('C:\\Users\\SILVERS\\Desktop\\ds_tutorial\\FoodBalanceSheets_E_Africa_NOFLAG.csv')

# 20
dc = fao.groupby(['Area'])
print(dc)
# Out:
#        Unnamed: 0  Area Code      Area  Item Code           Item  \
# 0               0          4   Algeria       2501     Population
# 1               1          4   Algeria       2501     Population
# 2               2          4   Algeria       2901    Grand Total
# 3               3          4   Algeria       2901    Grand Total
# 4               4          4   Algeria       2901    Grand Total
# ...           ...        ...       ...        ...            ...
# 60938       60938        181  Zimbabwe       2899  Miscellaneous
# 60939       60939        181  Zimbabwe       2899  Miscellaneous
# 60940       60940        181  Zimbabwe       2899  Miscellaneous
# 60941       60941        181  Zimbabwe       2899  Miscellaneous
# 60942       60942        181  Zimbabwe       2899  Miscellaneous
#
#        Element Code                                 Element             Unit  \
# 0               511           Total Population - Both sexes     1000 persons
# ...
